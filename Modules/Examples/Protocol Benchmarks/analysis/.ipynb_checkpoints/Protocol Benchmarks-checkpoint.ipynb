# %% [markdown]
# # Protocol Benchmarks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from functools import *
from glob import glob as list_files

# %%
try:
    files = list_files(os.environ['BENCH_RESULTS_DIR']+'/*.csv')
except:
    files = list_files("../bench-results/*.csv")
dfs = []
for file in files:
    dfs.append(pd.read_csv(file, delimiter=";"))

df = pd.concat(dfs)
df["latency"] = df["latency"] / 1000
df["unit"] = "ms" # fix unit
df
# Out:
#                       name   op                   args    send-time  \
# 0     Client1-iZH.7E-yUEaT  put          keyX1 valueX1  37345216738
# 1     Client1-iZH.7E-yUEaT  put          keyX2 valueX2  37345221083
# 2     Client1-iZH.7E-yUEaT  put          keyX3 valueX3  37345223911
# 3     Client1-iZH.7E-yUEaT  put          keyX4 valueX4  37345226679
# 4     Client1-iZH.7E-yUEaT  put          keyX5 valueX5  37345228897
# ...                    ...  ...                    ...          ...
# 9995  Client1-iZH.WA7wTEua  put    keyX9996 valueX9996  38008948861
# 9996  Client1-iZH.WA7wTEua  put    keyX9997 valueX9997  38008949144
# 9997  Client1-iZH.WA7wTEua  put    keyX9998 valueX9998  38008949433
# 9998  Client1-iZH.WA7wTEua  put    keyX9999 valueX9999  38008949760
# 9999  Client1-iZH.WA7wTEua  put  keyX10000 valueX10000  38008950054
#
#       receive-time   latency unit
# 0      37345220177  3.439294   ms
# 1      37345223863  2.779998   ms
# 2      37345226639  2.728817   ms
# 3      37345228858  2.179071   ms
# 4      37345231510  2.612936   ms
# ...            ...       ...  ...
# 9995   38008949143  0.282203   ms
# 9996   38008949432  0.287523   ms
# 9997   38008949759  0.325454   ms
# 9998   38008950053  0.293163   ms
# 9999   38008950430  0.376165   ms
#
# [30000 rows x 7 columns]

# %%
df.loc[df['name'] == "Client1-iZH.x4fsC2yk", 'name'] = 'bla'
df
# Out:
#                       name   op                   args    send-time  \
# 0     Client1-iZH.7E-yUEaT  put          keyX1 valueX1  37345216738
# 1     Client1-iZH.7E-yUEaT  put          keyX2 valueX2  37345221083
# 2     Client1-iZH.7E-yUEaT  put          keyX3 valueX3  37345223911
# 3     Client1-iZH.7E-yUEaT  put          keyX4 valueX4  37345226679
# 4     Client1-iZH.7E-yUEaT  put          keyX5 valueX5  37345228897
# ...                    ...  ...                    ...          ...
# 9995  Client1-iZH.XJSzH2wL  put    keyX9996 valueX9996  37437416279
# 9996  Client1-iZH.XJSzH2wL  put    keyX9997 valueX9997  37437416576
# 9997  Client1-iZH.XJSzH2wL  put    keyX9998 valueX9998  37437416870
# 9998  Client1-iZH.XJSzH2wL  put    keyX9999 valueX9999  37437417152
# 9999  Client1-iZH.XJSzH2wL  put  keyX10000 valueX10000  37437417436
#
#       receive-time   latency unit
# 0      37345220177  3.439294   ms
# 1      37345223863  2.779998   ms
# 2      37345226639  2.728817   ms
# 3      37345228858  2.179071   ms
# 4      37345231510  2.612936   ms
# ...            ...       ...  ...
# 9995   37437416575  0.295633   ms
# 9996   37437416870  0.293972   ms
# 9997   37437417151  0.281303   ms
# 9998   37437417435  0.283303   ms
# 9999   37437417808  0.372194   ms
#
# [20000 rows x 7 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(7,5))

for name in df["name"].unique():
    grouped = df[df["name"] == name].groupby({x: x // 100 for x in range(len(df))})["latency"].mean().plot(ax=ax, label=name)
    
ax.set_xlabel("number of queries in groups of 100")
ax.set_ylabel("latency [ms]")

ax.legend()
ax

plt.savefig(fname="latency.png", format="png")
